# %%
from src.feature_engineering.feature_engineering import DataProcessor

# %% [markdown]
# ## 1. Data Processing

# %%
processor = DataProcessor()

# %%
processor.pipeline()
# Out:
# c:\Programming\Ironhack\projects\Customer-Churn-Prediction\src\feature_engineering\feature_engineering.py:64: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   trends = self.dfs["transactions_clean"].groupby("customer_id").apply(self.calculate_trends)
# c:\Programming\Ironhack\projects\Customer-Churn-Prediction\src\feature_engineering\feature_engineering.py:66: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
# ...

# %%
display(processor.dfs["combined"].head())
print(processor.dfs["combined"].shape)
# Out:
#   customer_id signup_date   age  monthly_fee signup_year_month  country_DE  \
# 0     C100000  2022-01-31  58.0        16.51           2022-01       False
# 1     C100001  2022-12-30  56.0         8.99           2022-12       False
# 2     C100002  2021-10-05  19.0        43.68           2021-10       False
# 3     C100003  2022-07-18   NaN        27.14           2022-07       False
# 4     C100004  2022-02-04  46.0        55.60           2022-02        True
#
#    country_ES  country_FR  country_IT  country_NL  ...  usage_volatility  \
# 0        True       False       False       False  ...          1.852919
# 1        True       False       False       False  ...          2.235862
# 2       False       False       False        True  ...          2.333025
# 3        True       False       False       False  ...          2.361294
# 4       False       False       False       False  ...          2.327597
#
# ...

# %% [markdown]
# ## 2. Customer Data Visualisation

# %%
processor.plot_monthly_signups()

# %%
processor.plot_cohorts()

# %% [markdown]
# ## 3. Save Data

# %%
for df in ["combined", "support_processed", "customers_processed", "transactions_processed"]:
            processor.save_df(df)
